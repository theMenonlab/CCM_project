# %%
import numpy as np
import skimage.transform as skt
import matplotlib.pyplot as plt
import scipy.io as sio
import os
import skimage.transform as skt
import my_alg
import tensorflow as tf

# %%
ref_dir = 'G:/double_lens/paper/Reviewer/data/add_noise/ref2'
ccm_dir = 'G:/double_lens/paper/Reviewer/data/add_noise/ccm2'
#ccm_dir1 = 'D:/Lensless/Data/resolution/384/ccm_subBG'

# %%
file_lst = os.listdir( ccm_dir)

# %%
len( file_lst)
# Out:
# 300

# %%
ref_imgs = []
ref_imgs1 = []
ccm_imgs = []
ccm_imgs1 = []
reshape_shape = [128,128] #[128,128,3]
#b = 0
#for i in range(len( file_lst)):#len( file_lst)
#    i = i + 1;#9000 + 9000 + 2000#+ 11666 +11666 + 11668 + 4000    # 30000#+39000+3500
    
#    ccm_img_path = os.path.join( ccm_dir, '%i.mat'%i)
#    ccm_mat = sio.loadmat( ccm_img_path)
#    ccm_img = ccm_mat['imgHDR']
#    a = np.max(np.max(ccm_img))
#    print(a)
#    if b<a:
#        b = a
for ii in range(1):
    for i in range( len( file_lst)):#len( file_lst)28268
#        i = i+20000*(2)+500#+500+6500+6500#9000 + 9000 + 2000#+ 11666 +11666 + 11668 + 4000    # 30000#+39000+3500
        #ref_img1 = []
#        iii = i+1
        i = i
        ref_img_path1 = os.path.join( ref_dir, '%i.mat' % i)
        ref_mat1 = sio.loadmat( ref_img_path1, verify_compressed_data_integrity=False)
        ref_img1 = ref_mat1['objRef']
        m = np.max( ref_img1)+1
        if m>0:
            ref_img_path = os.path.join( ref_dir, '%i.mat' % i)
            ref_mat = sio.loadmat( ref_img_path, verify_compressed_data_integrity=False)

            ref_img = ref_mat['objRef']
#            ref_img = ref_img[0:447,0:447]
            ref_img = ref_img - np.min( ref_img)
            ref_img = ref_img / np.max( ref_img)
            ref_img = skt.resize( ref_img, reshape_shape)
            ref_imgs.append( ref_img)

            ccm_img_path = os.path.join( ccm_dir, '%i.mat'%i)
            ccm_mat = sio.loadmat( ccm_img_path)
            ccm_img = ccm_mat['imgHDR']
#            ccm_img = ccm_img[0:447,0:447]
            ccm_img = ccm_img - np.min( ccm_img)
        #ccm_img = ccm_img / b
            ccm_img = ccm_img / np.max( ccm_img)
            ccm_img = skt.resize( ccm_img, reshape_shape)
            ccm_imgs.append( ccm_img)

#            ref_img_path1 = os.path.join( ref_dir1, '%i.mat' % iii)
#            ref_mat1 = sio.loadmat( ref_img_path1, verify_compressed_data_integrity=False)

#            ref_img1 = ref_mat1['objRef1']
#            ref_img1 = ref_img1 - np.min( ref_img1)
#            ref_img1 = ref_img1 / np.max( ref_img1)
    #    ref_img = ref_img[1:129,1:129]
#            ref_img1 = skt.resize( ref_img1, reshape_shape)
#            ref_imgs1.append( ref_img1)
        
#        ccm_img_path1 = os.path.join( ccm_dir, '%i.mat'%iii)
#        ccm_mat = sio.loadmat( ccm_img_path1)
#        ccm_img = ccm_mat['imgHDR']
#        ccm_img = ccm_img - np.min( ccm_img)
        #ccm_img = ccm_img / b
#        ccm_img = ccm_img / np.max( ccm_img)
#        ccm_img = skt.resize( ccm_img1, reshape_shape)
#        ccm_imgs.append( ccm_img)
        if i % 100 == 0:
            print( i)
    
ref_imgs = np.array( ref_imgs)
#ref_imgs1 = np.array( ref_imgs1)
ccm_imgs = np.array( ccm_imgs)
#ccm_imgs1 = np.array( ccm_imgs1)
# Out:
# 0
# 100
# 200

# %%
np.save( 'G:/double_lens/paper/Reviewer/data/add_noise/ccm_neuron_for_addnoise_2021207.npy',ccm_imgs)
np.save( 'G:/double_lens/paper/Reviewer/data/add_noise/ref_neuron_for_addnoise_2021207.npy',ref_imgs)
#np.save( 'D:/BPRP/ref_imgs_128_26319_20201110_thred.npy',ref_imgs1)
#np.save( 'D:/Lensless/ccm_imgs_128_resolution_384_40000_20201031.npy',ccm_imgs)

# %%
ref_imgs = []
ref_imgs1 = []
ccm_imgs = []
ccm_imgs1 = []
reshape_shape = [128,128] #[128,128,3]
#b = 0
#for i in range(len( file_lst)):#len( file_lst)
#    i = i + 1;#9000 + 9000 + 2000#+ 11666 +11666 + 11668 + 4000    # 30000#+39000+3500
    
#    ccm_img_path = os.path.join( ccm_dir, '%i.mat'%i)
#    ccm_mat = sio.loadmat( ccm_img_path)
#    ccm_img = ccm_mat['imgHDR']
#    a = np.max(np.max(ccm_img))
#    print(a)
#    if b<a:

for ii in range(1):
    for i in range(1215):#len( file_lst)28268
#        i = i+20000*(2)+500#+500+6500+6500#9000 + 9000 + 2000#+ 11666 +11666 + 11668 + 4000    # 30000#+39000+3500
        #ref_img1 = []
#        iii = i+1
        i1 = i*5
        ref_img_path1 = os.path.join( ccm_dir, '%i.mat' % i)
        ref_mat1 = sio.loadmat( ref_img_path1, verify_compressed_data_integrity=False)
        ref_img1 = ref_mat1['imgHDR']
        m = np.max( ref_img1)+1
        if m>0:

            ccm_img_path = os.path.join( ccm_dir, '%i.mat'%i1)
            ccm_mat = sio.loadmat( ccm_img_path)
            ccm_img1 = ccm_mat['imgHDR']

            ccm_img_path = os.path.join( ccm_dir, '%i.mat'%(i1+1))
            ccm_mat = sio.loadmat( ccm_img_path)
            ccm_img2 = ccm_mat['imgHDR']
            
            ccm_img_path = os.path.join( ccm_dir, '%i.mat'%(i1+2))
            ccm_mat = sio.loadmat( ccm_img_path)
            ccm_img3 = ccm_mat['imgHDR']
        
            ccm_img_path = os.path.join( ccm_dir, '%i.mat'%(i1+3))
            ccm_mat = sio.loadmat( ccm_img_path)
            ccm_img4 = ccm_mat['imgHDR']
            
            ccm_img_path = os.path.join( ccm_dir, '%i.mat'%(i1+4))
            ccm_mat = sio.loadmat( ccm_img_path)
            ccm_img5 = ccm_mat['imgHDR']
#            ccm_img = ccm_img[200:1500,200:1500]

            
            ccm_img = (ccm_img1 + ccm_img2 + ccm_img3 + ccm_img4 + ccm_img5)/5
            
            ccm_img = ccm_img - np.min( ccm_img)
        #ccm_img = ccm_img / b
            ccm_img = ccm_img / np.max( ccm_img)
            ccm_img = skt.resize( ccm_img, reshape_shape)
            ccm_imgs.append( ccm_img)
        if i % 100 == 0:
            print( i)
    
#ref_imgs = np.array( ref_imgs)
#ref_imgs1 = np.array( ref_imgs1)
ccm_imgs = np.array( ccm_imgs)
#ccm_imgs1 = np.array( ccm_imgs1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200

# %%
np.save( 'G:/worms/ccm_worms_20211008_5avg.npy',ccm_imgs)

# %%
ref_dir = 'G:/MEB/08052021/ref2'
ccm_dir = 'G:/MEB/08052021/ccm1'
file_lst = os.listdir( ccm_dir)
ref_imgs = []
ref_imgs1 = []
ccm_imgs = []
ccm_imgs1 = []
reshape_shape = [128,128] #[128,128,3]

for ii in range(1):
    for i in range( len( file_lst)):#len( file_lst)28268
        i = i
        ref_img_path1 = os.path.join( ref_dir, '%i.mat' % i)
        ref_mat1 = sio.loadmat( ref_img_path1, verify_compressed_data_integrity=False)
        ref_img1 = ref_mat1['objRef2']
        m = np.max( ref_img1)+1
        if m>0:
            ref_img_path = os.path.join( ref_dir, '%i.mat' % i)
            ref_mat = sio.loadmat( ref_img_path, verify_compressed_data_integrity=False)

            ref_img = ref_mat['objRef2']
            ref_img = ref_img[200:1500,200:1500]
            ref_img = ref_img - np.min( ref_img)
            ref_img = ref_img / np.max( ref_img)
            ref_img = skt.resize( ref_img, reshape_shape)
            ref_imgs.append( ref_img)

            ccm_img_path = os.path.join( ccm_dir, '%i.mat'%i)
            ccm_mat = sio.loadmat( ccm_img_path)
            ccm_img = ccm_mat['imgHDR1']
            ccm_img = ccm_img - np.min( ccm_img)
            ccm_img = ccm_img / np.max( ccm_img)
            ccm_img = skt.resize( ccm_img, reshape_shape)
            ccm_imgs.append( ccm_img)

        if i % 100 == 0:
            print( i)
    
ref_imgs = np.array( ref_imgs)
ccm_imgs = np.array( ccm_imgs)
np.save( 'G:/MEB/08052021/ccm_doublecannula_20210805_bead_sample_2_smallersize.npy',ccm_imgs)
np.save( 'G:/MEB/08052021/ref_doublecannula_20210805_bead_sample_2_smallersize.npy',ref_imgs)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
ref_dir2 = 'G:/double_lens/neuron/layer1/ref2'
ccm_dir2 = 'G:/double_lens/neuron/layer1/ccm2'
file_lst = os.listdir( ccm_dir2)
ref_imgs = []
ref_imgs1 = []
ccm_imgs = []
ccm_imgs1 = []
reshape_shape = [128,128] #[128,128,3]

for ii in range(1):
    for i in range( len( file_lst)):#len( file_lst)28268
        i = i
        ref_img_path1 = os.path.join( ref_dir2, '%i.mat' % i)
        ref_mat1 = sio.loadmat( ref_img_path1, verify_compressed_data_integrity=False)
        ref_img1 = ref_mat1['objRef']
        m = np.max( ref_img1)
        if m>0:
            ref_img_path = os.path.join( ref_dir2, '%i.mat' % i)
            ref_mat = sio.loadmat( ref_img_path, verify_compressed_data_integrity=False)

            ref_img = ref_mat['objRef']
            ref_img = ref_img - np.min( ref_img)
            ref_img = ref_img / np.max( ref_img)
            ref_img = skt.resize( ref_img, reshape_shape)
            ref_imgs.append( ref_img)

            ccm_img_path = os.path.join( ccm_dir2, '%i.mat'%i)
            ccm_mat = sio.loadmat( ccm_img_path)
            ccm_img = ccm_mat['imgHDR']
            ccm_img = ccm_img - np.min( ccm_img)
            ccm_img = ccm_img / np.max( ccm_img)
            ccm_img = skt.resize( ccm_img, reshape_shape)
            ccm_imgs.append( ccm_img)
        if i % 100 == 0:
            print( i)
    
ref_imgs = np.array( ref_imgs)
ccm_imgs = np.array( ccm_imgs)
np.save( 'G:/double_lens/neuron/layer1/ccm_doublelens_with_coverslip_20210518_1.npy',ccm_imgs)
np.save( 'G:/double_lens/neuron/layer1/ref_doublelens_with_coverslip_20210518_1.npy',ref_imgs)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
ref_dir3 = 'G:/double_lens/neuron/layer1_rebuild/ref'
ccm_dir3 = 'G:/double_lens/neuron/layer1_rebuild/ccm'
file_lst = os.listdir( ccm_dir3)
ref_imgs = []
ref_imgs1 = []
ccm_imgs = []
ccm_imgs1 = []
reshape_shape = [128,128] #[128,128,3]

for ii in range(1):
    for i in range( len( file_lst)):#len( file_lst)28268
        i = i
        ref_img_path1 = os.path.join( ref_dir3, '%i.mat' % i)
        ref_mat1 = sio.loadmat( ref_img_path1, verify_compressed_data_integrity=False)
        ref_img1 = ref_mat1['objRef']
        m = np.max( ref_img1)
        if m>0:
            ref_img_path = os.path.join( ref_dir3, '%i.mat' % i)
            ref_mat = sio.loadmat( ref_img_path, verify_compressed_data_integrity=False)

            ref_img = ref_mat['objRef']
            ref_img = ref_img - np.min( ref_img)
            ref_img = ref_img / np.max( ref_img)
            ref_img = skt.resize( ref_img, reshape_shape)
            ref_imgs.append( ref_img)

            ccm_img_path = os.path.join( ccm_dir3, '%i.mat'%i)
            ccm_mat = sio.loadmat( ccm_img_path)
            ccm_img = ccm_mat['imgHDR']
            ccm_img = ccm_img - np.min( ccm_img)
            ccm_img = ccm_img / np.max( ccm_img)
            ccm_img = skt.resize( ccm_img, reshape_shape)
            ccm_imgs.append( ccm_img)
        if i % 100 == 0:
            print( i)
    
ref_imgs = np.array( ref_imgs)
ccm_imgs = np.array( ccm_imgs)
np.save( 'G:/double_lens/neuron/layer1_rebuild/ccm_doublelens_with_coverslip_20210518_1.npy',ccm_imgs)
np.save( 'G:/double_lens/neuron/layer1_rebuild/ref_doublelens_with_coverslip_20210518_1.npy',ref_imgs)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
np.save( 'G:/double_lens/neuron/layer3/ccm_doublelens_with_coverslip_20210518_1.npy',ccm_imgs)
np.save( 'G:/double_lens/neuron/layer3/ref_doublelens_with_coverslip_20210518_1.npy',ref_imgs)

# %%
ref_dir4 = 'G:/double_lens/20210511/layer4/ref'
ccm_dir4 = 'G:/double_lens/20210511/layer4/ccm'
file_lst = os.listdir( ccm_dir4)
ref_imgs = []
ref_imgs1 = []
ccm_imgs = []
ccm_imgs1 = []
reshape_shape = [128,128] #[128,128,3]

for ii in range(1):
    for i in range( len( file_lst)):#len( file_lst)28268
        i = i
        ref_img_path1 = os.path.join( ref_dir4, '%i.mat' % i)
        ref_mat1 = sio.loadmat( ref_img_path1, verify_compressed_data_integrity=False)
        ref_img1 = ref_mat1['objRef']
        m = np.max( ref_img1)
        if m>0:
            ref_img_path = os.path.join( ref_dir4, '%i.mat' % i)
            ref_mat = sio.loadmat( ref_img_path, verify_compressed_data_integrity=False)

            ref_img = ref_mat['objRef']
            ref_img = ref_img - np.min( ref_img)
            ref_img = ref_img / np.max( ref_img)
            ref_img = skt.resize( ref_img, reshape_shape)
            ref_imgs.append( ref_img)

            ccm_img_path = os.path.join( ccm_dir4, '%i.mat'%i)
            ccm_mat = sio.loadmat( ccm_img_path)
            ccm_img = ccm_mat['imgHDR']
            ccm_img = ccm_img - np.min( ccm_img)
            ccm_img = ccm_img / np.max( ccm_img)
            ccm_img = skt.resize( ccm_img, reshape_shape)
            ccm_imgs.append( ccm_img)
        if i % 100 == 0:
            print( i)
    
ref_imgs = np.array( ref_imgs)
ccm_imgs = np.array( ccm_imgs)
np.save( 'G:/double_lens/20210511/layer4/ccm_doublelens_with_coverslip_20210512.npy',ccm_imgs)
np.save( 'G:/double_lens/20210511/layer4/ref_doublelens_with_coverslip_20210512.npy',ref_imgs)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
ref_imgs.shape
# Out:
# (130, 128, 128)

# %%
np.save( 'D:/Lensless/ccm_imgs_128_grayemnist_addccm_20000_20210122_1.npy',ccm_imgs)
np.save( 'D:/Lensless/ref_imgs_128_grayemnist_addccm_20000_20210122_1.npy',ref_imgs)

# %%
a = np.load( 'D:/Lensless/depth23456/ref/ref_imgs_128_depth23456_100000_20201020_1.npy')
a1 = np.load( 'D:/Lensless/depth23456/ref/ref_imgs_128_depth23456_100000_20201020_2.npy')
#a2 = np.load( 'E:/Lensless/eval_ref/ref_imgs_128_coloremnist_40000_20200504_1.npy')

# %%
mnist_x1.shape,mnist_x2.shape,mnist_x3.shape,mnist_x4.shape
# Out:
# ((23940, 128, 128), (22001, 128, 128), (22157, 128, 128), (20440, 128, 128))

# %%
b_train = np.row_stack((a, a1))
b_train1 = np.row_stack((b_train, a2))

# %%
np.save( 'D:/Lensless/coloremnist_depth/ref_imgs_128_depth23456_100000_20201026_eval',b_train1)

# %%
mnist_x1 = np.load('G:/double_lens/neuron/layer1_rebuild/ref_doublelens_with_coverslip_20210518_1.npy')
#mnist_b1 = np.load('G:/double_lens/neuron/layer1_rebuild/ccm_doublelens_with_coverslip_20210518_1.npy')
mnist_x2 = np.load('G:/double_lens/neuron/layer2/ref_doublelens_with_coverslip_20210518_1.npy')
#mnist_b2 = np.load('G:/double_lens/neuron/layer2/ccm_doublelens_with_coverslip_20210518_1.npy')
mnist_x3 = np.load('G:/double_lens/neuron/layer3/ref_doublelens_with_coverslip_20210518_1.npy')
#mnist_b3 = np.load('G:/double_lens/neuron/layer3/ccm_doublelens_with_coverslip_20210518_1.npy')
mnist_x4 = np.load('G:/double_lens/neuron/layer4/ref_doublelens_with_coverslip_20210518_1.npy')
#mnist_b4 = np.load('G:/double_lens/neuron/layer4/ccm_doublelens_with_coverslip_20210518_1.npy')

# %%
x_test = mnist_x1[:1000]
b_test = mnist_b1[:1000]

x_eval = mnist_x1[1000:4000]
b_eval = mnist_b1[1000:4000]

x_train = mnist_x1[4000:24000]
b_train = mnist_b1[4000:24000]

x_test1 = mnist_x2[:1000]
b_test1 = mnist_b2[:1000]

x_eval1 = mnist_x2[1000:4000]
b_eval1 = mnist_b2[1000:4000]

x_train1 = mnist_x2[4000:24000]
b_train1 = mnist_b2[4000:24000]

# %%
x_test3 = mnist_x3[:1000]
b_test3 = mnist_b3[:1000]

x_eval3 = mnist_x3[1000:4000]
b_eval3 = mnist_b3[1000:4000]

x_train3 = mnist_x3[4000:24000]
b_train3 = mnist_b3[4000:24000]

x_test4 = mnist_x4[:1000]
b_test4 = mnist_b4[:1000]

x_eval4 = mnist_x4[1000:4000]
b_eval4 = mnist_b4[1000:4000]

x_train4 = mnist_x4[4000:24000]
b_train4 = mnist_b4[4000:24000]

# %%
mnist_test_x = np.row_stack((x_test, x_test1))
mnist_test_b = np.row_stack((b_test, b_test1))
mnist_eval_x = np.row_stack((x_eval, x_eval1))
mnist_eval_b = np.row_stack((b_eval, b_eval1))
mnist_train_x = np.row_stack((x_train, x_train1))
mnist_train_b = np.row_stack((b_train, b_train1))

# %%
mnist_test_x1 = np.row_stack((x_test3, x_test4))
mnist_test_b1 = np.row_stack((b_test3, b_test4))
mnist_eval_x1 = np.row_stack((x_eval3, x_eval4))
mnist_eval_b1 = np.row_stack((b_eval3, b_eval4))
mnist_train_x1 = np.row_stack((x_train3, x_train4))
mnist_train_b1 = np.row_stack((b_train3, b_train4))

# %%
mnist_test_x2 = np.row_stack((mnist_test_x, mnist_test_x1))
mnist_test_b2 = np.row_stack((mnist_test_b, mnist_test_b1))
mnist_eval_x2 = np.row_stack((mnist_eval_x, mnist_eval_x1))
mnist_eval_b2 = np.row_stack((mnist_eval_b, mnist_eval_b1))
mnist_train_x2 = np.row_stack((mnist_train_x, mnist_train_x1))
mnist_train_b2 = np.row_stack((mnist_train_b, mnist_train_b1))

# %%
mnist_x1 = []
mnist_b1 = []
mnist_x2 = []
mnist_b2 = []
mnist_x3 = []
mnist_b3 = []
mnist_x4 = []
mnist_b4 = []

# %%
x_test3 = []
b_test3 = []

x_eval3 = []
b_eval3 = []

x_train3 = []
b_train3 = []

x_test4 = []
b_test4 = []

x_eval4 = []
b_eval4 = []

x_train4 = []
b_train4 = []

# %%
np.save( 'G:/double_lens/neuron/ref_imgs_128_depth1234_4000test_20210525_test',mnist_test_x2)
np.save( 'G:/double_lens/neuron/ccm_imgs_128_depth1234_4000test_20210525_test', mnist_test_b2)
np.save( 'G:/double_lens/neuron/ref_imgs_128_depth1234_4000test_20210525_eval',mnist_eval_x2)
np.save( 'G:/double_lens/neuron/ccm_imgs_128_depth1234_4000test_20210525_eval', mnist_eval_b2)
#np.save( 'G:/double_lens/20210511/ref_imgs_128_depth1234_4000_20210515_train1',mnist_train_x)
#np.save( 'G:/double_lens/20210511/ccm_imgs_128_depth1234_4000_20210515_train1',mnist_train_b)
np.save( 'G:/double_lens/neuron/ref_imgs_128_depth1234_4000test_20210525_train',mnist_train_x2)

# %%
np.save( 'G:/double_lens/neuron/ccm_imgs_128_depth1234_4000test_20210525_train',mnist_train_b2)

# %%
ref_img1 = skt.resize( ref_img, reshape_shape)

# %%
mnist_test_x2.shape
# Out:
# (4000, 128, 128)

# %%
print(a[39985])
# Out:
# 3.0

# %%
ccm_label = np.squeeze(ccm_img)

# %%
import my_alg

# %%
np.save( 'D:/Lensless/coloremnist_view/ref/ccm_imgs_128_coloremnist_view_40000_20201024_1',x_train)
np.save( 'D:/Lensless/coloremnist_view/ref/ccm_imgs_128_coloremnist_view_40000_20201024_2',x_train1)

# %%
np.save( 'D:/Lensless/coloremnist_view/ref_imgs_128_coloremnist_view_40000_20201024_eval',x_eval)

# %%
np.save( 'D:/Lensless/coloremnist_depth/ref/ccm_imgs_128_depth23456_100000_20201026_1',x_train)
np.save( 'D:/Lensless/coloremnist_depth/ref/ccm_imgs_128_depth23456_100000_20201026_2', x_train1)
np.save( 'D:/Lensless/coloremnist_depth/ref/ccm_imgs_128_depth23456_100000_20201026_3',x_train2)
np.save( 'D:/Lensless/coloremnist_depth/ref_imgs_128_depth23456_100000_20201026_eval',y_eval)
#np.save( 'D:/Lensless/coloremnist_depth/ref/label_imgs_128_depth2345_80000_20201023_2', y_train1)
#np.save( 'D:/Lensless/coloremnist_depth/ref/label_imgs_128_depth2345_80000_20201023_1',y_train)
#np.save( 'D:/Neuron/ccm1/ref_imgs_3output_128_Neuron123_20200420_train1', b_train1)
#np.save( 'D:/Lensless/color_emojis_35403/ref/ref_imgs_128_coloremojis_20890_20200518_2',x_train2)
#np.save( 'D:/Lensless/color_emojis_35403/ref/ref_imgs_128_coloremojis_20890_20200518_3',x_train3)

# %%
ref_imgs = []
ref_img1 = []
ref_imgs1 = np.zeros((128,128),dtype = 'float32')
ccm_imgs = []
reshape_shape = [128,128] #[128,128]

for i in range(17484):#len( file_lst)
    i = i+16979 + 16514
    ref_img1 = []
    ref_img_path = os.path.join( ref_dir, '%i.mat' % i)
    ref_mat = sio.loadmat( ref_img_path, verify_compressed_data_integrity=False)
    
    ref_img = ref_mat['objRef']
    ref_img = ref_img - np.min( ref_img)
    ref_img = ref_img / np.max( ref_img)
    ref_img = skt.resize( ref_img, reshape_shape)    
#    if i < 20380:#33493:
#        ref_img[7:10,112:115] = 0.5
#    elif i < 40678:#50982:
#        ref_img[7:10,112:115] = 0.5
#        ref_img[17:20,120:123] = 0.5
#    else:
#        ref_img[7:10,112:115] = 0.5
#        ref_img[17:20,120:123] = 0.5
#        ref_img[27:30,112:115] = 0.5

    if i < 33493:#33493:
        ref_img1.append( ref_img)
        ref_img1.append( ref_imgs1)
        ref_img1.append( ref_imgs1)
        ref_img1 = np.array( ref_img1)
    elif i < 50977:#50982:
        ref_img1.append( ref_imgs1)
        ref_img1.append( ref_img)
        ref_img1.append( ref_imgs1)
        ref_img1 = np.array( ref_img1)
    else:
        ref_img1.append( ref_imgs1)
        ref_img1.append( ref_imgs1)
        ref_img1.append( ref_img)
        ref_img1 = np.array( ref_img1)
        
    ref_img1 = ref_img1.transpose(2,1,0) 
    ref_imgs.append( ref_img1)
#    ref_imgs.append( ref_img)
    
    ccm_img_path = os.path.join( ccm_dir, '%i.mat'%i)
    ccm_mat = sio.loadmat( ccm_img_path)
    ccm_img = ccm_mat['imgHDR']
    ccm_img = ccm_img - np.min( ccm_img)
    ccm_img = ccm_img / np.max( ccm_img)
    ccm_img = skt.resize( ccm_img, reshape_shape)
    ccm_imgs.append( ccm_img)
 
    if i % 100 == 0:
        print( i)
    
ref_imgs = np.array( ref_imgs)
ccm_imgs = np.array( ccm_imgs)

np.random.seed(47)
arg_random = np.random.permutation( len( ref_imgs))
NUM_TRAIN = int( 0.9 * len( ref_imgs))

x_train = ref_imgs[ arg_random[:NUM_TRAIN]]
b_train = ccm_imgs[arg_random[:NUM_TRAIN]]

x_test = ref_imgs[ arg_random[NUM_TRAIN:]]
b_test = ccm_imgs[ arg_random[NUM_TRAIN:]]

np.save( './Neuron/ref_imgs_3output_128_Neuron123_layer1_20200403_test2',x_test)
np.save( './Neuron/ccm_imgs_3output_128_Neuron123_layer1_20200403_test2', b_test)
np.save( './Neuron/ref_imgs_3output_128_Neuron123_layer1_20200403_train2',x_train)
np.save( './Neuron/ccm_imgs_3output_128_Neuron123_layer1_20200403_train2', b_train)
# Out:
# 33500
# 33600
# 33700
# 33800
# 33900
# 34000
# 34100
# 34200
# 34300
# 34400
# 34500
# 34600
# 34700
# 34800
# 34900
# 35000
# 35100
# 35200
# 35300
# 35400
# 35500
# 35600
# 35700
# 35800
# 35900
# 36000
# 36100
# 36200
# 36300
# 36400
# 36500
# 36600
# 36700
# 36800
# 36900
# 37000
# 37100
# 37200
# 37300
# 37400
# 37500
# 37600
# 37700
# 37800
# 37900
# 38000
# 38100
# 38200
# 38300
# 38400
# 38500
# 38600
# 38700
# 38800
# 38900
# 39000
# 39100
# 39200
# 39300
# 39400
# 39500
# 39600
# 39700
# 39800
# 39900
# 40000
# 40100
# 40200
# 40300
# 40400
# 40500
# 40600
# 40700
# 40800
# 40900
# 41000
# 41100
# 41200
# 41300
# 41400
# 41500
# 41600
# 41700
# 41800
# 41900
# 42000
# 42100
# 42200
# 42300
# 42400
# 42500
# 42600
# 42700
# 42800
# 42900
# 43000
# 43100
# 43200
# 43300
# 43400
# 43500
# 43600
# 43700
# 43800
# 43900
# 44000
# 44100
# 44200
# 44300
# 44400
# 44500
# 44600
# 44700
# 44800
# 44900
# 45000
# 45100
# 45200
# 45300
# 45400
# 45500
# 45600
# 45700
# 45800
# 45900
# ...

# %%
ref_imgs = []
ref_img1 = []
ref_imgs1 = np.zeros((128,128),dtype = 'float32')
ccm_imgs = []
reshape_shape = [128,128] #[128,128]

for i in range(16785):#len( file_lst)
    i = i+16979 + 16514 + 17484
    ref_img1 = []
    ref_img_path = os.path.join( ref_dir, '%i.mat' % i)
    ref_mat = sio.loadmat( ref_img_path, verify_compressed_data_integrity=False)
    
    ref_img = ref_mat['objRef']
    ref_img = ref_img - np.min( ref_img)
    ref_img = ref_img / np.max( ref_img)
    ref_img = skt.resize( ref_img, reshape_shape)    
#    if i < 20380:#33493:
#        ref_img[7:10,112:115] = 0.5
#    elif i < 40678:#50982:
#        ref_img[7:10,112:115] = 0.5
#        ref_img[17:20,120:123] = 0.5
#    else:
#        ref_img[7:10,112:115] = 0.5
#        ref_img[17:20,120:123] = 0.5
#        ref_img[27:30,112:115] = 0.5

    if i < 33493:#33493:
        ref_img1.append( ref_img)
        ref_img1.append( ref_imgs1)
        ref_img1.append( ref_imgs1)
        ref_img1 = np.array( ref_img1)
    elif i < 50977:#50982:
        ref_img1.append( ref_imgs1)
        ref_img1.append( ref_img)
        ref_img1.append( ref_imgs1)
        ref_img1 = np.array( ref_img1)
    else:
        ref_img1.append( ref_imgs1)
        ref_img1.append( ref_imgs1)
        ref_img1.append( ref_img)
        ref_img1 = np.array( ref_img1)
        
    ref_img1 = ref_img1.transpose(2,1,0) 
    ref_imgs.append( ref_img1)
#    ref_imgs.append( ref_img)
    
    ccm_img_path = os.path.join( ccm_dir, '%i.mat'%i)
    ccm_mat = sio.loadmat( ccm_img_path)
    ccm_img = ccm_mat['imgHDR']
    ccm_img = ccm_img - np.min( ccm_img)
    ccm_img = ccm_img / np.max( ccm_img)
    ccm_img = skt.resize( ccm_img, reshape_shape)
    ccm_imgs.append( ccm_img)
 
    if i % 100 == 0:
        print( i)
    
ref_imgs = np.array( ref_imgs)
ccm_imgs = np.array( ccm_imgs)

np.random.seed(47)
arg_random = np.random.permutation( len( ref_imgs))
NUM_TRAIN = int( 0.9 * len( ref_imgs))

x_train = ref_imgs[ arg_random[:NUM_TRAIN]]
b_train = ccm_imgs[arg_random[:NUM_TRAIN]]

x_test = ref_imgs[ arg_random[NUM_TRAIN:]]
b_test = ccm_imgs[ arg_random[NUM_TRAIN:]]

np.save( './Neuron/ref_imgs_3output_128_Neuron123_layer1_20200403_test3',x_test)
np.save( './Neuron/ccm_imgs_3output_128_Neuron123_layer1_20200403_test3', b_test)
np.save( './Neuron/ref_imgs_3output_128_Neuron123_layer1_20200403_train3',x_train)
np.save( './Neuron/ccm_imgs_3output_128_Neuron123_layer1_20200403_train3', b_train)
# Out:
# 51000
# 51100
# 51200
# 51300
# 51400
# 51500
# 51600
# 51700
# 51800
# 51900
# 52000
# 52100
# 52200
# 52300
# 52400
# 52500
# 52600
# 52700
# 52800
# 52900
# 53000
# 53100
# 53200
# 53300
# 53400
# 53500
# 53600
# 53700
# 53800
# 53900
# 54000
# 54100
# 54200
# 54300
# 54400
# 54500
# 54600
# 54700
# 54800
# 54900
# 55000
# 55100
# 55200
# 55300
# 55400
# 55500
# 55600
# 55700
# 55800
# 55900
# 56000
# 56100
# 56200
# 56300
# 56400
# 56500
# 56600
# 56700
# 56800
# 56900
# 57000
# 57100
# 57200
# 57300
# 57400
# 57500
# 57600
# 57700
# 57800
# 57900
# 58000
# 58100
# 58200
# 58300
# 58400
# 58500
# 58600
# 58700
# 58800
# 58900
# 59000
# 59100
# 59200
# 59300
# 59400
# 59500
# 59600
# 59700
# 59800
# 59900
# 60000
# 60100
# 60200
# 60300
# 60400
# 60500
# 60600
# 60700
# 60800
# 60900
# 61000
# 61100
# 61200
# 61300
# 61400
# 61500
# 61600
# 61700
# 61800
# 61900
# 62000
# 62100
# 62200
# 62300
# 62400
# 62500
# 62600
# 62700
# 62800
# 62900
# 63000
# 63100
# 63200
# 63300
# 63400
# ...

# %%
fig = my_alg.show_random_sampels( ccm_imgs,5,5,)

# %%
ref = np.load('E:/beads/ref_imgs_128_1_12_2_3_beads_50096_20200427.npy')
ccm = np.load('E:/beads/ccm_imgs_128_1_12_2_3_beads_50096_20200427.npy')

# %%
#y=np.arange(len( mnist_b1)) #50783 neuron
#y[:16514 ] = 0
#y[16514:33998 ] = 1
#y[33998: ] = 2

#y = np.arange( len( mnist_b)) #bead
#y[0:16722 ] = 0
#y[16722:33561 ] = 1
#y[33561:50096 ] = 2
a = 33561 - 16722
b = 50096 - 33561
print(a),print(b)
# Out:
# 16839
# 16535
# (None, None)

# %%
ref.shape
# Out:
# (50096, 128, 128)

# %%
ref1 = ref[0:16510,:,:]
ref16514 = ref[16722:33232,:,:]
ref133998 = ref[33561:50071,:,:]

# %%
ccm1 = ccm[0:16510,:,:]
ccm16514 = ccm[16722:33232,:,:]
ccm133998 = ccm[33561:50071,:,:]

# %%
ref_imgs = np.array(ref_imgs)
ref_imgs.shape
# Out:
# (16510, 128, 128)

# %%
print(np.max(ref_imgs[7,:,:]))
# Out:
# 0.80564547

# %%
a = ccm123[7,:,:]

# %%
a = a - np.min( a)
a = a / np.max( a)

# %%
print(np.max(a))
# Out:
# 2.7330332

# %%
ref1_ = ref1[7,:,:]
ref16514_ = ref16514[7,:,:]
ref133998_ = ref133998[7,:,:]

# %%
print(np.max(ref133998_))
# Out:
# 0.7924411

# %%
ccm_imgs = ref_imgs

# %%
ref_imgs = ref123

# %%
ccm_imgs.shape,ref_imgs.shape
# Out:
# ((16510, 128, 128), (16510, 128, 128, 3))

# %%
np.save('D:/bead/ref_imgs_128_3layeradd_modified1_16510_20200525.npy',ref_imgs)
np.save('D:/bead/ccm_imgs_128_3layeradd_modified1_16510_20200525.npy',ccm_imgs)

# %%
model.compile(optimizer=keras.optimizers.Adam(1e-3, amsgrad= True), loss=ave_cross_en, metrics=['mae'])

# %%
model.fit(b_train, x_train, batch_size=16, epochs=17, verbose=1,validation_data= ( b_eval, x_eval))
# Out:
# Train on 26000 samples, validate on 3000 samples
# WARNING:tensorflow:From C:\Users\Rg\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/17
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-10-a84ab9483522> in <module>
# ----> 1 model.fit(b_train, x_train, batch_size=16, epochs=17, verbose=1,validation_data= ( b_eval, x_eval))
#
# ...

# %%
model.save('E:/3D_data result/beads/128_e17_b16_newlayer135added_3D_800test_allrandom_37random_float32_20200910')

# %%
import gzip
with gzip.open('H:/train-images-idx3-ubyte.gz', 'rb') as f:
    file_content = f.read()

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %% [raw]
# print(y_train[0])

# %%
print(y_train[0])
# Out:
# 9

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.random.random((16, 16))
plt.imshow(ccm_imgs[0])
plt.show()

# %%
from sklearn import preprocessing
a = np.random.random((16, 16))
 
# standardization of dependent variables
standard = preprocessing.scale(a)
print(standard)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-8ada51c2708d> in <module>
# ----> 1 from sklearn import preprocessing
#       2 a = np.random.random((16, 16))
#       3
#       4 # standardization of dependent variables
#       5 standard = preprocessing.scale(a)
#
# ModuleNotFoundError: No module named 'sklearn'
